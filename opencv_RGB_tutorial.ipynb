# %% [markdown]
# <a href="https://colab.research.google.com/github/wonjae124/2021_Lab_project/blob/main/opencv_RGB_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/123.jpg')
plt.imshow(image)

# %%
(B, G, R) = cv2.split(image)

plt.imshow(B)
B.shape
# Out:
# (1000, 1600)

# %%
plt.imshow(G)

# %%
plt.imshow(R)

# %%
merged = cv2.merge([B,G,R])
plt.imshow(merged)

# %%
zeros = np.zeros(image.shape[:2], dtype = 'uint8')
zeros.shape
# Out:
# (1000, 1600)

# %%
image = cv2.imread('/123.jpg')
plt.imshow(image)
print(image)
print(image.shape)
# Out:
# [[[157  78  39]
#   [160  81  42]
#   [160  81  42]
#   ...
#   [156 123 107]
#   [156 124 105]
#   [156 124 105]]
#
#  [[158  79  40]
#   [159  80  41]
#   [159  80  41]
#   ...
#   [156 123 107]
#   [156 124 105]
#   [156 124 105]]
#
#  [[160  84  42]
#   [159  83  41]
#   [159  83  41]
#   ...
#   [158 125 106]
#   [158 125 106]
#   [158 125 106]]
#
#  ...
#
#  [[ 29 145  98]
#   [ 34 152 104]
#   [ 43 162 117]
#   ...
#   [122 141 146]
#   [116 138 144]
#   [125 149 155]]
#
#  [[ 20 136  89]
#   [ 23 139  92]
#   [ 27 143  96]
#   ...
#   [120 139 144]
#   [122 145 153]
#   [111 137 144]]
#
#  [[ 15 131  84]
#   [ 17 133  86]
#   [ 23 137  90]
#   ...
#   [132 150 157]
#   [149 172 180]
#   [120 147 157]]]
# (1000, 1600, 3)

# %%
px = image[100,100]
print(px)
#B,G,R 순서임
# Out:
# [188 157 132]

# %%
blue = image[100, 100,0]
print(blue) # Blue 픽셀만 엑세스

green = image[100, 100, 1]
print(green) 

red = image[100,100,2]
print(red)
# Out:
# 188
# 157
# 132

# %%
image[100,100]= [255,255,255]
print(image[100,100])
# Out:
# [255 255 255]

# %%
print(image.shape)
# return row, columns, channels
# Out:
# (1000, 1600, 3)

# %%
print(image.size)
#return All image pixels
# Out:
# 4800000

# %%
print(image.dtype)
# Out:
# uint8

# %% [markdown]
# # Reigin of images (이미지를 복사하는 역할)

# %%
ball = image[280:340, 330:390]
image[273:333, 100:160] = ball

plt.imshow(ball)

# %%
plt.imshow(image)

# %% [markdown]
# # cv2.split 보다 numpy indexing(아래와 같이 콜론으로 구분하는 것)이 연산량이 적다.

# %%
b = image[:,:,0]
g = image[:,:,1]
r = image[:,:,2]

# %%
plt.imshow(b)

# %%
plt.imshow(g)

# %%
plt.imshow(r)
