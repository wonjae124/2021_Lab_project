# %% [markdown]
# <a href="https://colab.research.google.com/github/wonjae124/2021_Lab_project/blob/main/autoencodertutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt #이미지를 띄울 떄 사용할 예정
import numpy as np
import pandas as pd
import random
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

# %%
#데이터셋 불러오기
train_dataset = torchvision.datasets.MNIST('./data',train=True, download=True)
test_dataset = torchvision.datasets.MNIST('./data',train=False,download=True) # ? 굳이 두번 다운로드 해야 되나?
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
#데이터셋 전처리하기
train_transform = transforms.Compose([transforms.ToTensor(),]) #compose 함수로 여러 트랜스폼(변환)을 하나로 compose구성한다.
test_transform = transforms.Compose([transforms.ToTensor()],) 

train_dataset.transform = train_transform
test_dataset.transform = test_transform

# %%
train_dataset.transform.size()

a= torch.tensor([0,0]) 
b = torch.tensor([[0,0],[1,1]])
c = torch.tensor([[[0,0],[1,1],[2,2]]])
#print(a)
#print(b)
#print(c)
#train_dataset[0][0].size()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-087f6410dcc3> in <module>()
# ----> 1 train_dataset.transform.size()
#       2
#       3 a= torch.tensor([0,0])
#       4 b = torch.tensor([[0,0],[1,1]])
#       5 c = torch.tensor([[[0,0],[1,1],[2,2]]])
#
# AttributeError: 'Compose' object has no attribute 'size'

# %%
#데이터셋 나누기.
m=len(train_dataset)

train_data,val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)]) #random_split을 이용해서 데이터셋을 slice 할 수 있다. 왼쪽은 ?이고 우측은 정답이다.
batch_size = 256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size) #Dataloader를 사용하는 이유? 쉽게 데이터셋을 slice할 수 있다?
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True) #우리가 할 것은 shuffle을 안해도 되지?

# %%
print(train_data.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-458ac6761828> in <module>()
# ----> 1 print(train_data.shape)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataset.py in __getattr__(self, attribute_name)
#      81             return function
#      82         else:
# ---> 83             raise AttributeError
#      84
#      85     @classmethod
#
# AttributeError:

# %%
#Encoder, decodr
